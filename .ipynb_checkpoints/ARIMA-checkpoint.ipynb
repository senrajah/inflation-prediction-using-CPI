# %% [markdown]
# ## 5. ARIMA
#
# ARIMA models are used to analyse time series regression, and provide more accurate results than linear regression. Uni-variate ARIMA models allow us to forecast future values from past values of the same variable, while multi-variate ARIMA models allow us to incorporate exogenous variables into the forecast.
#
# First, we import the essential libraries and datasets as usual.

# %%
# Importing essential libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms as mtransforms
import seaborn as sb
import pandas as pd
from datetime import datetime
from functools import reduce

# ARIMA libraries
# !pip install statsmodels
# !pip install pmdarima
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
# Out:
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in /opt/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /opt/anaconda3/lib/python3.11/site-packages (from statsmodels) (1.11.4)
# Requirement already satisfied: pandas>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from statsmodels) (2.1.4)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.11/site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Requirement already satisfied: pmdarima in /opt/anaconda3/lib/python3.11/site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (2.1.4)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (68.2.2)
# Requirement already satisfied: packaging>=17.1 in /opt/anaconda3/lib/python3.11/site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
# Import cleaned datasets
bie_data = pd.read_csv("data/cleaned/cleaned_bie.csv")
cpi_data = pd.read_csv("data/cleaned/cleaned_cpi.csv")
neer_data = pd.read_csv("data/cleaned/cleaned_neer.csv")
oil_data = pd.read_csv("data/cleaned/cleaned_oil.csv")
ppi_data = pd.read_csv("data/cleaned/cleaned_ppi.csv")
sp_data = pd.read_csv("data/cleaned/cleaned_sp.csv")
unemp_data = pd.read_csv("data/cleaned/cleaned_unemp.csv")

# Store in dataset_list
dataset_list = {
                'BIE': bie_data,
                'NEER': neer_data,
                'Oil': oil_data,
                'PPI': ppi_data,
                'S&P500': sp_data,
                'Unemp': unemp_data
            }

# Inner join each dataset to the CPI dataset for comparison
df_list = {k:pd.merge(v, cpi_data, how='inner', on='Date') for (k,v) in dataset_list.items()}

# %% [markdown]
# ### Useful Functions
#
# Let's define a function to calculate the accuracy based on Mean Average Percentage Error (MAPE). As compared to MSE, this provides a quicker and easier way to look at percentage accuracy as it provides a value from 0-1. After finding MAPE, we can take 1-MAPE as a quick way to find the accuracy.
#
# Additionally, we will still show our MSE for a more specific way of understanding the errors in our model.

# %%
def calc_acc(actual, forecast):
    actual_np = np.array(actual)
    forecast_np = np.array(forecast)
    mape = np.mean(np.abs(forecast_np - actual_np)/np.abs(actual_np))
    mse = np.mean(np.square(forecast_np - actual_np)/np.abs(actual_np))
    print(f'Accuracy of Model = {round((1-mape) * 100, 1)}%')
    print(f'MSE = {mse}')

# %% [markdown]
# ### Create ARIMA Model for CPI
#
# Next, we use the auto_arima() function from the pmdarima library which can help us auto-generate an ARIMA model with the best parameters.

# %%
forecast_date = '2022'
model = pm.auto_arima(cpi_data[cpi_data['Date'] < forecast_date][['Value']], start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=661.921, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1041.686, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=672.192, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=723.580, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1372.535, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=663.631, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=633.700, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=666.521, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=624.386, Time=0.25 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=621.092, Time=0.31 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=619.061, Time=0.26 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=655.724, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=664.863, Time=0.04 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=620.378, Time=0.11 sec
#
# Best model:  ARIMA(3,1,1)(0,0,0)[0] intercept
# Total fit time: 1.642 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  900
# Model:               SARIMAX(3, 1, 1)   Log Likelihood                -303.531
# Date:                Mon, 18 Nov 2024   AIC                            619.061
# Time:                        04:05:09   BIC                            647.869
# Sample:                             0   HQIC                           630.067
#                                 - 900
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0028      0.004      0.635      0.526      -0.006       0.012
# ar.L1          1.5214      0.030     49.927      0.000       1.462       1.581
# ar.L2         -0.7271      0.032    -23.081      0.000      -0.789      -0.665
# ar.L3          0.1975      0.018     10.904      0.000       0.162       0.233
# ma.L1         -0.9146      0.026    -35.332      0.000      -0.965      -0.864
# sigma2         0.1149      0.002     47.132      0.000       0.110       0.120
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              9045.54
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):              37.24   Skew:                            -1.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### Understanding the ARIMA model generated by AUTOARIMA
#
# The ARIMA(p,q,d) function has 3 parameters p, q, and d.
#
# - ‘p’ is the order of the ‘Auto Regressive’ (AR) term. It refers to the number of lags of Y to be used as predictors.
# - ‘q’ is the order of the ‘Moving Average’ (MA) term. It refers to the number of lagged forecast errors that should go into the ARIMA Model.
# - 'd' is the number of differencing required to make the time series stationary. It refers to the number times the data needs to be differenced (i.e. take the current value minus the previous value).
#
# For our CPI ARIMA model above, which has the function ARIMA(3,1,1)
#
# #### Testing our CPI ARIMA model
#
# Before running the auto_arima() function above, we split the train and test dataset at 2022.

# %%
# Forecast
n_periods = len(cpi_data[cpi_data['Date'] >= forecast_date])
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = np.arange(len(cpi_data[cpi_data['Date'] < forecast_date]), len(cpi_data[cpi_data['Date'] < forecast_date])+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize=(14, 10))
plt.xticks(np.arange(0, 10000, 120)) # show x-ticks every 10 years
plt.plot(cpi_data[cpi_data['Date'] < forecast_date]['Date'], cpi_data[cpi_data['Date'] < forecast_date]['Value'])
plt.plot(cpi_data[cpi_data['Date'] >= forecast_date]['Date'], cpi_data[cpi_data['Date'] >= forecast_date]['Value'])
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("CPI with ARIMA Forecast")
plt.show()

# %%
# Calculate Accuracy
calc_acc(cpi_data[cpi_data['Date'] >= forecast_date][['Value']], fc_series)
# Out:
# Accuracy of Model = 96.5%
# MSE = 0.5652228184374926

# %% [markdown]
# #### Conclusion from our CPI ARIMA Model
#
# The actual values from our test dataset are in orange, while the values predicted by the ARIMA model are in green. It looks to be a decent predictor, usually remaining in the estimated grey range, with the exception of the post Covid-19 inflation spike. It also has a 96.5% accuracy after calculation of MAPE.

# %% [markdown]
# ### Introducing Exogenous Variables Into the Forecast
#
# Apart from using past values to predict future values of CPI, ARIMA also allows us to introduce exogenous variables. For our project, we can now introduce our other variables like CO2, PPI, unemployment, etc.
#
# Let us first define a function to help us get the ARIMA models for CPI with a single exogenous variable each.

# %%
def univariate_exogenous(var, forecast_date='2022', x_tick_interval=10000):
    model = pm.auto_arima(y=df_list[var][df_list[var]['Date'] < forecast_date][['Value_y']], start_p=1, start_q=1,
                        X=df_list[var][df_list[var]['Date'] < forecast_date][['Value_x']],
                        test='adf',       # use adftest to find optimal 'd'
                        max_p=3, max_q=3, # maximum p and q
                        m=1,              # frequency of series
                        d=None,           # let model determine 'd'
                        seasonal=False,   # No Seasonality
                        start_P=0,
                        D=0, 
                        trace=True,
                        error_action='ignore',  
                        suppress_warnings=True, 
                        stepwise=True)

    # Forecast
    n_periods = len(df_list[var][df_list[var]['Date'] >= forecast_date])
    fc, confint = model.predict(n_periods=n_periods, return_conf_int=True, X=df_list[var][df_list[var]['Date'] >= forecast_date][['Value_x']]
    )
    index_of_fc = np.arange(len(df_list[var][df_list[var]['Date'] < forecast_date]), len(df_list[var][df_list[var]['Date'] < forecast_date])+n_periods)

    # make series for plotting purpose
    fc_series = pd.Series(fc, index=index_of_fc)
    lower_series = pd.Series(confint[:, 0], index=index_of_fc)
    upper_series = pd.Series(confint[:, 1], index=index_of_fc)

    # Calculate Accuracy
    calc_acc(df_list[var][df_list[var]['Date'] >= forecast_date][['Value_y']], fc_series)

    # Plot
    plt.figure(figsize=(14, 10))
    plt.xticks(np.arange(0, x_tick_interval, 120))
    plt.plot(df_list[var][df_list[var]['Date'] < forecast_date]['Date'], df_list[var][df_list[var]['Date'] < forecast_date]['Value_y'])
    plt.plot(df_list[var][df_list[var]['Date'] >= forecast_date]['Date'], df_list[var][df_list[var]['Date'] >= forecast_date]['Value_y'])
    plt.plot(fc_series, color='darkgreen')
    plt.fill_between(lower_series.index, 
                    lower_series, 
                    upper_series, 
                    color='k', alpha=.15)

    plt.title(f'CPI with ARIMA Forecast (Exogenous Variable: {var})')
    plt.show()

# %% [markdown]
# #### CPI ARIMA Model with Exogenous Variable of NEER

# %%
univariate_exogenous('NEER', forecast_date='2022', x_tick_interval=10000)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=496.490, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=592.967, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=506.362, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=502.313, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=728.681, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=496.778, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=493.558, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=493.354, Time=0.03 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=493.408, Time=0.03 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=495.385, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=547.613, Time=0.02 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0] intercept
# Total fit time: 0.440 seconds
# Accuracy of Model = 95.1%
# MSE = 0.9382270053024885

# %% [markdown]
# #### CPI ARIMA Model with Exogenous Variable of BIE

# %%
univariate_exogenous('BIE', forecast_date='2022', x_tick_interval=10000)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=198.751, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=199.818, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=197.784, Time=0.01 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=196.905, Time=0.01 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.117 seconds
# Accuracy of Model = 93.7%
# MSE = 1.7553079742672832

# %% [markdown]
# #### CPI ARIMA Model with Exogenous Variable of Oil Price

# %%
univariate_exogenous('Oil', forecast_date='2022', x_tick_interval=10000)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=484.863, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=546.322, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=488.284, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=486.236, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=782.054, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=486.066, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=482.928, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=483.637, Time=0.04 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=484.995, Time=0.18 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=485.433, Time=0.18 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=484.044, Time=0.07 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=484.347, Time=0.19 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=484.995, Time=0.11 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0] intercept
# Total fit time: 1.208 seconds
# Accuracy of Model = 96.5%
# MSE = 0.526898317318662

# %% [markdown]
# #### CPI ARIMA Model with Exogenous Variable of PPI

# %%
univariate_exogenous('PPI', forecast_date='2022', x_tick_interval=10000)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=200.867, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=372.771, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=201.824, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=247.304, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=777.318, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=203.859, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=125.919, Time=0.25 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=203.124, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=128.660, Time=0.30 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=131.437, Time=0.34 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=205.084, Time=0.13 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=105.845, Time=0.38 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=111.145, Time=0.41 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=117.273, Time=0.32 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=103.426, Time=0.38 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=122.615, Time=0.34 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=125.806, Time=0.26 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=107.527, Time=0.40 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=125.856, Time=0.18 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=109.651, Time=0.31 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 4.534 seconds
# Accuracy of Model = 96.7%
# MSE = 0.48102722210000676

# %% [markdown]
# #### CPI ARIMA Model with Exogenous Variable of S&P500

# %%
univariate_exogenous('S&P500', forecast_date='2022', x_tick_interval=10000)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=558.842, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=676.462, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=568.724, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=567.753, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=855.070, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=569.258, Time=0.13 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=561.976, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=556.042, Time=0.11 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=556.643, Time=0.15 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=559.887, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=634.434, Time=0.09 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0] intercept
# Total fit time: 1.193 seconds
# Accuracy of Model = 95.1%
# MSE = 0.9436833537961646

# %% [markdown]
# #### CPI ARIMA Model with Exogenous Variable of Unemployment Rate

# %%
univariate_exogenous('Unemp', forecast_date='2018', x_tick_interval=10000)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=519.588, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=805.474, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=527.905, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=553.163, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1126.710, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=521.268, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=487.692, Time=0.24 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=521.946, Time=0.06 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=483.516, Time=0.29 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=488.083, Time=0.33 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=478.466, Time=0.34 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=482.938, Time=0.30 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=486.775, Time=0.38 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=477.097, Time=0.30 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=478.983, Time=0.29 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=481.402, Time=0.20 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=479.056, Time=0.33 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=488.121, Time=0.13 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=481.478, Time=0.24 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 3.833 seconds
# Accuracy of Model = 97.4%
# MSE = 0.3142067532403233

# %% [markdown]
# ### Multi Exogenous Variables
#
# Now let us try to combine the exogenous factors and see if we can create a better ARIMA model.

# %%
import matplotlib.dates as mdates

# Merge the values and plot a pairplot
dataset_list_values = {
    k: v.rename(columns={'Value': k})[['Date', k]] for k, v in dataset_list.items()
}
dataset_list_values['CPI'] = cpi_data.rename(columns={'Value': 'CPI'})[['Date', 'CPI']]
merged_values = reduce(lambda left,right: pd.merge(left,right,on='Date', how='inner'), dataset_list_values.values())
merged_values.columns = ['Date'] + list(dataset_list.keys()) + ['CPI']

forecast_date = '2021'
model = pm.auto_arima(y=merged_values[merged_values['Date'] < forecast_date][['CPI']], start_p=1, start_q=1,
                        X=merged_values[merged_values['Date'] < forecast_date][['BIE', 'NEER', 'Oil', 'PPI', 'S&P500', 'Unemp']],
                        test='adf',       # use adftest to find optimal 'd'
                        max_p=3, max_q=3, # maximum p and q
                        m=1,              # frequency of series
                        d=None,           # let model determine 'd'
                        seasonal=False,   # No Seasonality
                        start_P=0,
                        D=0, 
                        trace=True,
                        error_action='ignore',  
                        suppress_warnings=True, 
                        stepwise=True)

# Forecast
n_periods = len(merged_values[merged_values['Date'] >= forecast_date]['Date'])
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True, X=merged_values[merged_values['Date'] >= forecast_date][['BIE', 'NEER', 'Oil', 'PPI', 'S&P500', 'Unemp']]
)
index_of_fc = np.arange(len(merged_values[merged_values['Date'] < forecast_date]['Date']), len(merged_values[merged_values['Date'] < forecast_date]['Date'])+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Calculate Accuracy
calc_acc(merged_values[merged_values['Date'] < forecast_date][['CPI']], fc_series)

# Plotting the historical and forecasted data
plt.figure(figsize=(14, 10))

# Plot historical data (up to the forecast date)
plt.plot(merged_values[merged_values['Date'] < forecast_date]['Date'], 
         merged_values[merged_values['Date'] < forecast_date]['CPI'], label='Historical CPI', color='blue')

# Plot actual CPI data (after the forecast date)
plt.plot(merged_values[merged_values['Date'] >= forecast_date]['Date'], 
         merged_values[merged_values['Date'] >= forecast_date]['CPI'], label='Actual CPI', color='orange', linestyle='--')

# Plot forecast data (after the forecast date)
plt.plot(fc_series.index, fc_series, label='Forecasted CPI', color='darkgreen', linewidth=2)

# Plot the confidence interval
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=0.15, label='Confidence Interval')

# Customize plot
plt.xlabel('Date')
plt.ylabel('CPI Value')
plt.title('CPI Forecast (ARIMA Model with Exogenous Variables)')

# Add legend
plt.legend()

plt.gca().xaxis.set_visible(False) 

# Show grid lines for minor ticks (optional)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Show plot
plt.tight_layout()
plt.show()
# # Plot
# plt.figure(figsize=(14, 10))
# plt.xticks(np.arange(0, 100, 12))
# plt.plot(merged_values[merged_values['Date'] < forecast_date]['Date'], merged_values[merged_values['Date'] < forecast_date]['CPI'])
# plt.plot(merged_values[merged_values['Date'] >= forecast_date]['Date'], merged_values[merged_values['Date'] >= forecast_date]['CPI'])
# plt.plot(fc_series, color='darkgreen', label='Forecasted CPI')
# plt.fill_between(lower_series.index, 
#                 lower_series, 
#                 upper_series, 
#                 color='k', alpha=.15)

# plt.title(f'CPI with ARIMA Forecast (All 8 Exogenous Variables)')
# plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=335.415, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=421.471, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=335.070, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=364.857, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=334.709, Time=0.05 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=335.327, Time=0.07 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=336.796, Time=0.04 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=338.619, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=336.707, Time=0.04 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0]
# Total fit time: 0.439 seconds
# Accuracy of Model = 85.1%
# MSE = 6.189130659305147

# %% [markdown]
# #### Conclusion from Multi Exogenous Variable ARIMA Model
#
# The accuracy is significantly lower and MSE significantly higher than the CPI-only ARIMA model, and all the ARIMA models with a single exogenous variable. This could mean overfitting, and hence, it seems that ARIMA is best used with a single exogenous variable, and in the case of CPI, that will be with a single variable of unemployment rates.
#
# However, on closer analysis, this dip also seems to be a Covid-19 dip. As such, from observation, this model seems to be our most accurate model, as it is the only model which looks to follow the trend of the actual values (orange line) the most closely.
